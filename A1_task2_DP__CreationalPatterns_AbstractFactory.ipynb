# %% [markdown]
# # Design Patterns Module - Assignment 1. Creational Patterns

# %% [markdown]
# ## Task 2. Implementing **Abstract Factory** in Python - 10 points

# %% [markdown]
# 1. Imagine that you need to develop a Food App, where different types of Foods can be created like *Vegetarian* and *Non-Vegetarian*.
#
# 2. Among these 2 categories there are multiple individual products or objects:
# * for the Vegetarian category: Veg Burger, Veg Pizza, Veg Noodles
# * for the Non-Vegetarian category: Non-Veg Burger, Non-Veg Pizza, Non-Veg Noodles, Non-Veg Cutlet
#
# 3. Use the following UML Diagram to apply Abstract Factory Pattern to develop the required App.

# %% [markdown]
# ![image.png](attachment:image.png)
